# %% [markdown]
# # Laboratório 2

# %% [markdown]
# ## Tarefa 1
#
# ### Carregue o nó de Tenda dos Milagres (da versão em inglês Tent of Miracles) em Python e mostre o conteúdo JSON.

# %%
import requests
import io
import json

url_template = "http://dbpedia.org/data/{concept}.{format}"

concept = "Tent_of_Miracles_(novel)"
format = "jsod"

concept = concept.replace(" ", "_")

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
js = data.json()
print(json.dumps(js, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tent_of_Miracles_(novel)"
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Tent of Miracles (novel)",
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/French_New_Wave"
#                }
#             },
#             "http://purl.org/dc/terms/subject": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Modernist_novels"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/ontology/WrittenWork"
#                }
#             },
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Template:According_to_whom"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#comment": "Tent of Miracles (Portuguese: Tenda dos Milagres) is a Brazilian Modernist novel. It was written by Jorge Amado in 1967 and published the following year. It was later adapted to a 1977 Cinema Novo (Nouvelle Vague) film by director/screenplay writer Nelson Pereira dos Santos.",
#             "http://dbpedia.org/ontology/abstract": "La bottega dei miracoli \u00e8 un romanzo di Jorge Amado pubblicato nel 1960. Come altri romanzi dell&#39;autore (ad esempio Tieta d&#39;Agreste e Teresa Batista) \u00e8 un testo composito, con un intreccio zigzagante fra analessi e prolessi, con mutamenti di voci narranti ed inserti di materiale eterogeneo.\u00c8 possibile che l&#39;evento scatenante del racconto (la visita del famoso scienziato) sia stato ispirato dall&#39;esperienza vissuta; in quello stesso 1960, infatti, Jean Paul Sartre e Simone De Beauvoir visitarono il Brasile su invito dello stesso Amado: la visita divenne un evento mediatico, celebrato in numerose manifestazioni istituzionali.",
#             "http://dbpedia.org/property/pubDate": "1969",
#             "http://dbpedia.org/property/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://rdf.freebase.com/ns/m.02xrs4"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "974212123",
#             "http://dbpedia.org/property/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://dbpedia.org/ontology/author": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Jorge_Amado"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tenda dos Milagres",
#             "http://dbpedia.org/property/englishPubDate": "1971",
#             "http://dbpedia.org/ontology/country": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/property/name": "Tent of Miracles",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Novel"
#                }
#             },
#             "http://dbpedia.org/property/titleOrig": "Tenda dos Milagres",
#             "http://dbpedia.org/ontology/publisher": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Brazil"
#                }
#             },
#             "http://dbpedia.org/ontology/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)?oldid=974212123&ns=0"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageLength": "5253",
#             "http://purl.org/dc/elements/1.1/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/language": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Portuguese_language"
#                }
#             },
#             "http://dbpedia.org/ontology/wikiPageID": "623351",
#             "http://dbpedia.org/property/publisher": "Martins, Sao Paulo, Brazil",
#             "http://dbpedia.org/property/caption": "First edition",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tent_of_Miracles_(novel)"
#                }
#             }
#          }
#       ],
#       "__count": "1"
#    }
# }

# %% [markdown]
# ## Tarefa 2
# ### Recupere via Python e mostre o autor de Tenda dos Milagres?

# %%
#BASTA PRINTAR O LINK DO AUTOR DE ACORDO COM A SUBDIVISÃO da DBPEDIA
author = js["d"]["results"][0]["http://dbpedia.org/property/author"]["__deferred"]["uri"]
print("Autor de A Tenda dos Milagres: " + author)
# Out:
# Autor de A Tenda dos Milagres: http://dbpedia.org/resource/Jorge_Amado

# %% [markdown]
# ## Tarefa 3
# ### Quais os termos usados para Aspirina (consulta JSON/MeSH em Python)?

# %%
url_template = "https://id.nlm.nih.gov/mesh/lookup/descriptor?label={concept}&match={match}&limit={limit}"

#FOI SUBSTITUIDO O CONCEITO PARA ASPYRINE (aspirina em inglês), contudo, não foi encontrada nenhuma refêrencia exata.
concept = "Aspyrine"
match = "exact"
limit = "20"

concept = concept.replace(" ", "%20")

url = url_template.replace("{concept}", concept)\
                  .replace("{match}", match)\
                  .replace("{limit}", limit)

data = requests.get(url)
json_mi = data.json()
print(json.dumps(json_mi, indent=3))
# Out:
# []

# %% [markdown]
# ## Tarefa 4
# ### Escolha algum lugar no OpenStreetMap e elabore a mesma sequência de três chamadas de serviços para o seu conceito.

# %%
#FOI ESCOLHIDA A TORRE DE LONDRES (TOWER OF LONDON) PARA A TAREFA

url_template = "http://nominatim.openstreetmap.org/search?format={format}&q={query}"
format = "json"
query = "Tower of London"

url = url_template.replace("{format}", format)\
                  .replace("{query}", query)

data = requests.get(url)
museum_ref = data.json()

url_template = "https://api.openstreetmap.org/api/0.6/{element_type}/{id}.{format}"

element_type = "way"
id = str(museum_ref[0]["osm_id"])
format = "json"

url = url_template.replace("{element_type}", element_type)\
                  .replace("{id}", id)\
                  .replace("{format}", format)

data = requests.get(url)
museum_way = data.json()

#OBTENDO O LINK DA DBPEDIA (en: TOWER OF LONDON)

url_template = "http://dbpedia.org/data/{concept}.{format}"
concept = museum_way["elements"][0]["tags"]["wikipedia"].replace(" ", "_")\
                                                        .replace("en:", "")
format = "jsod"

url = url_template.replace("{concept}", concept)\
                  .replace("{format}", format)

data = requests.get(url)
museum_dbpedia = data.json()
print(json.dumps(museum_dbpedia, indent=3))
# Out:
# {
#    "d": {
#       "results": [
#          {
#             "__metadata": {
#                "uri": "http://dbpedia.org/resource/Tower_of_London"
#             },
#             "http://dbpedia.org/ontology/wikiPageWikiLink": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Category:Castles_in_London"
#                }
#             },
#             "http://www.w3.org/1999/02/22-rdf-syntax-ns#type": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/class/yago/DefensiveStructure103171356"
#                }
#             },
#             "http://www.w3.org/2002/07/owl#sameAs": {
#                "__deferred": {
#                   "uri": "http://ga.dbpedia.org/resource/T\u00far_Londan"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#label": "Londresko dorrea",
#             "http://dbpedia.org/property/wikiPageUsesTemplate": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/
#             "http://dbpedia.org/property/built": "Re-built: 1285",
#             "http://dbpedia.org/ontology/wikiPageRevisionID": "1023301365",
#             "http://dbpedia.org/property/designation": "UK Grade I",
#             "http://schema.org/sameAs": {
#                "__deferred": {
#                   "uri": "http://viaf.org/viaf/128321639"
#                }
#             },
#             "http://www.w3.org/ns/prov#wasDerivedFrom": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tower_of_London?oldid=1023301365&ns=0"
#                }
#             },
#             "http://dbpedia.org/property/designation1Free2value": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Lists_of_World_Heritage_Sites"
#                }
#             },
#             "http://dbpedia.org/property/designation1Criteria": "ii, iv",
#             "http://xmlns.com/foaf/0.1/depiction": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Tower_of_London_viewed_from_the_River_Thames.jpg"
#                }
#             },
#             "http://dbpedia.org/property/mapWidth": "275",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#long": "-0.07611110806465149",
#             "http://dbpedia.org/property/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/London_Borough_of_Tower_Hamlets"
#                }
#             },
#             "http://www.w3.org/2000/01/rdf-schema#seeAlso": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Church_of_St_Peter_ad_Vincula"
#                }
#             },
#             "http://dbpedia.org/property/owner": "Queen Elizabeth II in right of the Crown",
#             "http://www.georss.org/georss/point": "51.50805555555556 -0.0761111111111111",
#             "http://dbpedia.org/ontology/wikiPageLength": "101530",
#             "http://purl.org/linguistics/gold/hypernym": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/Castle"
#                }
#             },
#             "http://dbpedia.org/property/designation1Free2name": "Region",
#             "http://dbpedia.org/property/mapCaption": "Location of the castle in central London",
#             "http://dbpedia.org/property/designation1Free1name": "Country",
#             "http://dbpedia.org/ontology/thumbnail": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Special:FilePath/Tower_of_London_viewed_from_the_River_Thames.jpg?width=300"
#                }
#             },
#             "http://dbpedia.org/property/visitationYear": "2019",
#             "http://dbpedia.org/property/designation1Date": "1988",
#             "http://xmlns.com/foaf/0.1/homepage": {
#                "__deferred": {
#                   "uri": "http://www.hrp.org.uk/TowerOfLondon/"
#                }
#             },
#             "http://dbpedia.org/property/designation1Free1value": "United Kingdom",
#             "http://dbpedia.org/property/name": "Tower of London",
#             "http://dbpedia.org/property/locmapin": "United Kingdom Central London",
#             "http://www.w3.org/2004/02/skos/core#exactMatch": {
#                "__deferred": {
#                   "uri": "http://globalwordnet.org/ili/i60417"
#                }
#             },
#             "http://dbpedia.org/property/wordnet_type": {
#                "__deferred": {
#                   "uri": "http://www.w3.org/2006/03/wn/wn20/instances/synset-monument-noun-2"
#                }
#             },
#             "http://xmlns.com/foaf/0.1/name": "Tower of London",
#             "http://dbpedia.org/property/designation1Number": "488",
#             "http://dbpedia.org/ontology/wikiPageID": "31165",
#             "http://xmlns.com/foaf/0.1/isPrimaryTopicOf": {
#                "__deferred": {
#                   "uri": "http://en.wikipedia.org/wiki/Tower_of_London"
#                }
#             },
#             "http://www.w3.org/2003/01/geo/wgs84_pos#geometry": "POINT(-0.076111108064651 51.508056640625)",
#             "http://www.w3.org/2003/01/geo/wgs84_pos#lat": "51.508056640625",
#             "http://dbpedia.org/property/designation1Type": "Cultural",
#             "http://dbpedia.org/ontology/location": {
#                "__deferred": {
#                   "uri": "http://dbpedia.org/resource/London_Borough_of_Tower_Hamlets"
#                }
#             },
#             "http://dbpedia.org/property/visitationNum": "2984499"
#          }
#       ],
#       "__count": "1"
#    }
# }
